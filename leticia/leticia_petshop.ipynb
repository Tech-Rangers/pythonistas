# %%
# aula 5

import random
align = "^" # ['<', '>', '^'] 
width = 15
style = "\33[1m"
nomes_pets = ["Luna", "Nina","Teo", "Amora"]
espécies = ["Tartaruga", "Cão", "Gato", "Peixe", "Hamister"]
idades = range(0,7)
pesos = ["3", "1", "10", "5", "0.5"]
nomes_donos = ["Juliana", "Leticia", "Vini"]

animais = [
    ["Koda", "Cão", 6, 18, "Vini"],
    ["Murphy", "Gato", 6, 5.5, "Juliana"]
]

def adicionar_pet ():
    for pet in nomes_pets:
        espécie = espécies [random.randrange(len(espécies))]
        idade = idades [random.randrange(len(idades))]
        peso = pesos [random.randrange(len(pesos))]
        nome_dono = nomes_donos [random.randrange(len(nomes_donos))]
        
    novo_pet = [pet, espécie, idade, peso, nome_dono]
    print(f'{color_green}O novo pet e: \033[0m {novo_pet}')
    animais.append(novo_pet)

adicionar_pet()

# %%
def adicionar_pet ():
    nome_pet = str(input('como seu pet se chama'))
    espécie = str(input('Qual o seu tipo pet?'))
    idade = int(input('Qual idade do seu pet?'))
    peso = str(input('Qual e o peso do seu pet(em kg)?'))
    nome_dono = str(input('Qual é o nome do seu  humano?'))
    pet = [nome_pet, espécie, idade, peso, nome_dono]
    print(f'{color_green}O novo pet é: \033[0m {pet} \n')
    animais.append(pet)

adicionar_pet()

print("")
message1 = 'Nome Pet'
message2 = 'Espécie'
message3 = 'Idade'
message4 = 'Peso(kg)'
message5 = 'Dono'
align = "^" # ['<', '>', '^'] 
width = 10
color_green = "\33[32m"
color_y= "\33[33m"
color_red= "\33[31m"
color_b= "\33[36m"
style = "\33[1m"
background = "\33[47m"
print(f'|{message1:{align}{width}}{message2:{align}{width}}{message3:{align}{width}}{message4:{align}{width}}{message5:{align}{width}}|') 
for animal in animais: 
    print(f'{animal}')

# %%
for animal in animais: 
    print(f'{animal}')
numero_de_animais = len(animais)
print(f'Total de animais: \033[0m {numero_de_animais}')
print("remoção")

animais_removidos = []
def remover_pet (nome_pet):
    for index, animal in enumerate(animais):
        
        if nome_pet in animal:
            print(f' O animal que vai embora e:  \033[0m {animal}')
            animais_removidos.append(animal)
            animais.remove(animal)
        else: 
            print("este pet nao esta cadastrado")
        
remover_pet("tuti")

for animal in animais:
    print(f"- {animal}")

numero_de_animais = len(animais)
print(f'tem animais: \033[0m {numero_de_animais}')

# %%
tem_animais = len(animais)
print(f" o numero de animais e: {tem_animais}")
print("carregando")
new_func()
def atualizar_animal(nome_pet):
    for animal in animais:
        if nome_pet in animal:
            resposta = input(f'O pet é: {animal}, voce quer adicionar qual pet? Sim ou Não')
            if resposta == "Sim":
                especie_nova = str(input('Qual o tipo o seu pet?'))
                idade_nova = int(input('Quantos anos tem o seu pet?'))
                peso_novo = float(input('Qual e o peso do seu pet?'))
            
                pet_atualizado = [animal[0], especie_nova, idade_nova, peso_novo, animal[4]]
                print(f'{O {animal} novo é: \033[0m {pet_atualizado}}')
                animais.append(pet_atualizado)
                animais.remove(animal)
            else: 
                 print("nao foi possivel atualizado")        
        else:
            if animal == animais:
                print(f'esse pet nao esta aqui')        

atualizar_animal("Tata")
print("esse pet esta aqui")
for animal in animais:
    print(f"{animal}")
numero_de_animais = len(animais)
print(f" tem : {numero_de_animais} animais")

# %%
print(f"o nome do pet e")
def encontra_pet_nome(nome_pet):
    for animal in animais:
        if nome_pet in animal[0]:
            print(f"{color_y}o pet {nome_pet} possui:\033[0m  {animal}\n")
        else:
            if animal == animais:
                print("Não encontramos este pet \n")
encontra_pet_nome("lilo")
