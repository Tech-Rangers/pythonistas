# %% [markdown]
# #I solemnly swear I am up to no good

# %%
import random

align = "^" # ['<', '>', '^'] 
width = 15
color_green = "\33[32m"
color_y= "\33[33m"
color_red= "\33[31m"
color_b= "\33[36m"
style = "\33[1m"
background = "\33[47m"

nomes_pets = ["Dona Florinda", "Matilde", "Medusa", "Einsten", "Mendel"]
espécies = ["Cachorro", "Gato", "Pássaro", "Réptil", "Peixe"]
idades = ["2", "5", "1", "8", "3"]
pesos = ["2.5", "2", "1", "8", "15"]
nomes_donos = ["Ana", "Savanna", "Carlos", "Gabriel", "Marcela", "Leiticia", "Juliana"]

animais = [
    ["Koda", "Cão", 6, 18, "Carlos"],
    ["Murphy", "Gato", 6, 5.5, "Juliana"],
]

def adicionar_pet ():
    for pet in nomes_pets:
        espécie = espécies [random.randrange(len(espécies))]
        idade = idades [random.randrange(len(idades))]
        peso = pesos [random.randrange(len(pesos))]
        nome_dono = nomes_donos [random.randrange(len(nomes_donos))]
        
        novo_pet = [pet, espécie, idade, peso, nome_dono]
        print(f'{color_green}O novo animal cadastrado é: \033[0m {novo_pet}')
        animais.append(novo_pet)

adicionar_pet()

print(f'{color_b}Todos animais são: \033[0m {animais}')
numero_de_animais = len(animais)
print("_______ Remoção___________")

def remover_pet ():
   
    for animal in animais:
        print(f'{color_red} {animal} \033[0m')
        if animal in animais:
            animais.remove(animal)
        else: 
            print("n tem o nome pet")
        
remover_pet()
print(f'Todos animais são: {animais}')
# Out:
# O novo animal cadastrado é:  ['Dona Florinda', 'Réptil', '1', '2', 'Carlos']
# O novo animal cadastrado é:  ['Matilde', 'Peixe', '2', '1', 'Leiticia']
# O novo animal cadastrado é:  ['Medusa', 'Réptil', '8', '15', 'Marcela']
# O novo animal cadastrado é:  ['Einsten', 'Gato', '1', '2.5', 'Leiticia']
# O novo animal cadastrado é:  ['Mendel', 'Pássaro', '1', '2', 'Gabriel']
# Todos animais são:  [['Koda', 'Cão', 6, 18, 'Carlos'], ['Murphy', 'Gato', 6, 5.5, 'Juliana'], ['Dona Florinda', 'Réptil', '1', '2', 'Carlos'], ['Matilde', 'Peixe', '2', '1', 'Leiticia'], ['Medusa', 'Réptil', '8', '15', 'Marcela'], ['Einsten', 'Gato', '1', '2.5', 'Leiticia'], ['Mendel', 'Pássaro', '1', '2', 'Gabriel']]
# _______ Remoção___________
#  ['Koda', 'Cão', 6, 18, 'Carlos']
#  ['Dona Florinda', 'Réptil', '1', '2', 'Carlos']
#  ['Medusa', 'Réptil', '8', '15', 'Marcela']
#  ['Mendel', 'Pássaro', '1', '2', 'Gabriel']
# ...

# %%
import random
numero_de_animais = len(animais)
print(f"  Número de animais: {numero_de_animais}")
print("_______Atualizar___________")

def atualizar_animal():
    for animal in animais:
        print(f'{color_y} O animal a ser atualizado será: \033[0m {animal}')
        if animal in animais:
            nova_especie = espécies [random.randrange(len(espécies))]
            nova_idade = idades [random.randrange(len(idades))]
            novo_peso = pesos [random.randrange(len(pesos))]
            
            pet_atualizado = [animal[0], nova_especie, nova_idade, novo_peso, animal[4]]
            print(f'{color_green}O animal atualizado é: \033[0m {pet_atualizado}')
            animais.remove(animal)
            animais.append(pet_atualizado)
        else: 
            print(f'este animal não está cadastrado')        
atualizar_animal()

print(f'Todos animais são: {animais}')
numero_de_animais = len(animais)
print(f"  Número de animais: {numero_de_animais}")

# message1 = 'Nome Pet'
# message2 = 'Espécie'
# message3 = 'Idade'
# message4 = 'Peso(kg)'
# message5 = 'Dono'
# print(f'|{message1:{align}{width}}{message2:{align}{width}}{message3:{align}{width}}{message4:{align}{width}}{message5:{align}{width}}|')
# Out:
#   Número de animais: 3
# _______Atualizar___________
#  O animal a ser atualizado será:  ['Murphy', 'Gato', 6, 5.5, 'Juliana']
# O animal atualizado é:  ['Murphy', 'Cachorro', '3', '15', 'Juliana']
#  O animal a ser atualizado será:  ['Einsten', 'Gato', '1', '2.5', 'Leiticia']
# O animal atualizado é:  ['Einsten', 'Peixe', '8', '2', 'Leiticia']
#  O animal a ser atualizado será:  ['Einsten', 'Peixe', '8', '2', 'Leiticia']
# O animal atualizado é:  ['Einsten', 'Cachorro', '3', '2.5', 'Leiticia']
# Todos animais são: [['Matilde', 'Peixe', '2', '1', 'Leiticia'], ['Murphy', 'Cachorro', '3', '15', 'Juliana'], ['Einsten', 'Cachorro', '3', '2.5', 'Leiticia']]
#   Número de animais: 3

# %%
import random
numero_de_animais = len(animais)
print(f"  Número de animais: {numero_de_animais}")
print("_______Buscar___________")

def buscar_animais_do_dono():
    for animal in animais:
        dono = animal[4]
        if  dono in animal in animais:
            print(f'{color_y} A \033[0m {dono} {color_y} é dono de: \033[0m {animal} e {animal}')
            if dono:
                print(f"{dono} é dono de mais de um pet")
        else:
            print('Não há castrado desta pessoa')
            
    
buscar_animais_do_dono()
# Out:
#   Número de animais: 3
# _______Buscar___________
#  A  Leiticia  é dono de:  ['Matilde', 'Peixe', '2', '1', 'Leiticia'] e ['Matilde', 'Peixe', '2', '1', 'Leiticia']
# Leiticia é dono de mais de um pet
#  A  Juliana  é dono de:  ['Murphy', 'Cachorro', '3', '15', 'Juliana'] e ['Murphy', 'Cachorro', '3', '15', 'Juliana']
# Juliana é dono de mais de um pet
#  A  Leiticia  é dono de:  ['Einsten', 'Cachorro', '3', '2.5', 'Leiticia'] e ['Einsten', 'Cachorro', '3', '2.5', 'Leiticia']
# Leiticia é dono de mais de um pet

# %%
# desafio extra pessoa hahaha pet shop (usar um FOR OU WHILE)

nome = str(input('Qual o nome do seu pet?'))
espécie = str(input('Qual a espécie do seu pet?'))
idade = int(input('Qual idade do seu pet?'))
peso = str(input('Qual o peso do seu pet(em kg)?'))
nome_dono = str(input('Qual é o seu nome(nome do dono)?'))

animal = [nome, espécie, idade, peso, nome_dono]
message1 = 'Nome Pet'
message2 = 'Espécie'
message3 = 'Idade'
message4 = 'Peso(kg)'
message5 = 'Dono'
align = "^" # ['<', '>', '^'] 
width = 10
color_green = "\33[32m"
color_y= "\33[33m"
color_red= "\33[31m"
color_b= "\33[36m"
style = "\33[1m"
background = "\33[47m"
print(f'|{message1:{align}{width}}{message2:{align}{width}}{message3:{align}{width}}{message4:{align}{width}}{message5:{align}{width}}|')  
print(f'{animal}')
# Out:
# | Nome Pet  Espécie    Idade    Peso(kg)    Dono   |
# ['koda', 'cao', 6, '18', 'carlos']

# %%
# aula 4 
livros_harry_potter = [
    "Harry Potter e a Pedra Filosofal",
    "Harry Potter e a Câmara Secreta",
    "Harry Potter e o Prisioneiro de Azkaban",
    "Harry Potter e o Cálice de Fogo",
    "Harry Potter e a Ordem da Fênix",
    "Harry Potter e o Enigma do Príncipe",
    "Harry Potter e as Relíquias da Morte"
]

livros_tolkien = [
    "O Hobbit",
    "A Sociedade do Anel",
    "As Duas Torres",
    "O Retorno do Rei",
    "O Silmarillion",
    "Contos Inacabados",
    "Os Filhos de Húrin"
]

livros_twilight = [
    "Crepúsculo",
    "Lua Nova",
    "Eclipse",
    "Amanhecer"
]


width = 80
color_green = "\33[32m"
color_y= "\33[33m"
color_red= "\33[31m"
color_b= "\33[36m"
style = "\33[1m"
background = "\33[47m"


# Primeiro livro
print(f"1º. Os primeiros livros de cada saga são: {color_green}{style}{livros_harry_potter[0]}, {livros_tolkien[0]} e {livros_twilight[0]}\033[0m")

# segundo livro
segundo_livro_hp = livros_harry_potter[1]
print(f"2º. Os segundos livros de cada saga são: {color_y}{style}{livros_harry_potter[1]}, {livros_tolkien[1]} e {livros_twilight[1]}\033[0m")

# último livro version python
ultimo_livro_hp = livros_harry_potter[-1]
print(f" LAST: O ultimo livro do HP: {color_green}{style}{ultimo_livro_hp}\033[0m")

#len - quantidade de itens da lista
numero_de_livros = len(livros_tolkien)
ultimo_livro_tolk = livros_tolkien[numero_de_livros-1]
print(f' LAST: O ultimo livro do tolkien é: {color_red}{style}{ultimo_livro_tolk}\033[0m')

# como  fazer sem o len
counter = 0
for livro in livros_twilight:
    counter = counter + 1
ultimo_livro_tw = livros_twilight[counter-1]
print(f" LAST: O último livro de twilight é: {color_b}{style}{ultimo_livro_tw}\033[0m")

# penúltimo
counter = 0
for livro in livros_twilight:
    counter = counter + 1
penultimo_livro_tw = livros_twilight[counter-2]
print(f"  O penúltimo livro de twilight é: {color_b}{style}{penultimo_livro_tw}\033[0m")

#com len
numero_de_livros = len(livros_harry_potter)
penultimo_livro_hp = livros_harry_potter[numero_de_livros-2]
print(f'  O penultimo livro do HP é: {color_green}{style}{penultimo_livro_hp}\033[0m')

#simples
penultimo_livro_tolk = livros_tolkien[-2]
print(f"  O penultimo livro do tolkien é: {color_red}{style}{penultimo_livro_tolk}\033[0m")

# Quantos livros cada saga possui
print(f"{style}     Quantos livros cada um possui:\033[0m")
numero_de_livros_tw = len(livros_twilight)
numero_de_livros_tolk = len(livros_tolkien)
numero_de_livros_hp = len(livros_harry_potter)
print(f"     Saga twilight: {numero_de_livros_tw}")
print(f"     Saga tolkien: {numero_de_livros_tolk}")
print(f"     Saga harry_potter: {numero_de_livros_hp}")


#desafio final
import random
pessoas = ["Ana", "Bruno", "Carlos", "Diana", "Eduardo", "Fernanda", "Gustavo", "Helena", "Igor", "Julia"]
saldo = 0
catalogo = livros_harry_potter + livros_tolkien + livros_twilight


def sortear_livro(catalogo: list[str]) -> str:
    return random.choice(catalogo)

def alugar_livros():
    livros_alugados = []
    livros_disponiveis = []
    pessoas_q_alugaram = []
    saldo = 0
    for livro in catalogo:
        livros_disponiveis.append(livro)

    for pessoa in pessoas:
        livro_escolhido = catalogo [random.randrange(len(catalogo))]
        if livro_escolhido in livros_alugados:
            print(f"Desculpe {pessoas}, mas o livro não está disponível")
        else:
            livros_alugados.append(livro_escolhido)
            livros_disponiveis.remove(livro_escolhido)
            pessoas_q_alugaram.append(pessoa)
        # print(f" A pessoa {pessoa} escolhei o livro é: {livro_escolhido}")
        # print(f" {color_green}{style} Lista de disponíveis é: \033[0m {livros_disponiveis}")
    
    
    numero_pess_alugaram = len(pessoas_q_alugaram)
    print(f'Número de pessoas que alugaram {numero_pess_alugaram}')    
    livros_devolvidos = []    

    for index in range(0,numero_pess_alugaram):
        pessoa = pessoas_q_alugaram[index]
        livro = livros_alugados[index]
        if random.randint(0, 10) % 2 == 0:
            livros_disponiveis.append(livro)
            livros_devolvidos.append(livro) 
            saldo = saldo + 10
        else:
            print(f'livro {livro} não foi devolvido pela pessoa {pessoa}!!!!!!')
    for livro in livros_devolvidos:
        livros_alugados.remove(livro)
    
    numero_livros_disp = len(livros_disponiveis)
    print(f" {color_red}{style} Lista alugados é: \033[0m {livros_alugados}")
    print(f" {color_green}{style} O nº de livros disponíveis: \033[0m {numero_livros_disp}")
    print(f"Saldo final da biblioteca é de R$ {saldo:.2f}")

alugar_livros()
# Out:
# 1º. Os primeiros livros de cada saga são: Harry Potter e a Pedra Filosofal, O Hobbit e Crepúsculo
# 2º. Os segundos livros de cada saga são: Harry Potter e a Câmara Secreta, A Sociedade do Anel e Lua Nova
#  LAST: O ultimo livro do HP: Harry Potter e as Relíquias da Morte
#  LAST: O ultimo livro do tolkien é: Os Filhos de Húrin
#  LAST: O último livro de twilight é: Amanhecer
#   O penúltimo livro de twilight é: Eclipse
#   O penultimo livro do HP é: Harry Potter e o Enigma do Príncipe
#   O penultimo livro do tolkien é: Contos Inacabados
#      Quantos livros cada um possui:
#      Saga twilight: 4
#      Saga tolkien: 7
#      Saga harry_potter: 7
# Desculpe ['Ana', 'Bruno', 'Carlos', 'Diana', 'Eduardo', 'Fernanda', 'Gustavo', 'Helena', 'Igor', 'Julia'], mas o livro não está disponível
# Número de pessoas que alugaram 9
# livro A Sociedade do Anel não foi devolvido pela pessoa Ana!!!!!!
# livro Harry Potter e o Cálice de Fogo não foi devolvido pela pessoa Bruno!!!!!!
# ...

# %%
#Qual o livro do meio de cada?
print(f"{style} Qual o livro do meio de cada?\033[0m")
#extra twilight
print(f"{color_b}{style} Twilight\033[0m")
numero_de_livros_tw = len(livros_twilight)
numero_tw_div = numero_de_livros_tw / 2
if numero_tw_div.is_integer():
    print("Não há um livro do meio, pois o numero de livros é par")
else:
    print(numero_tw_div)

#Tolkien
print(f" {color_red}{style}Tolkien\033[0m")
import math
numero_de_livros_tolk = len(livros_tolkien)
numero_tolk_div = numero_de_livros_tolk / 2
livro_tolk_arredond = math.floor(numero_tolk_div)

livro_tolk_meio = livros_tolkien[-livro_tk_meio]

if numero_tolk_div.is_integer():
    print("Não há um livro do meio, pois o numero de livros é par")
else:
    print(f"O livro do meio de tolk é: {livro_tolk_meio}")

#HP
print(f" {color_green}{style}Happy Potter\033[0m")
numero_de_livros = len(livros_harry_potter)
numero_hp_div = numero_de_livros_hp / 2
livro_hp_meio = math.ceil(numero_hp_div)
livro_HP_meio = livros_harry_potter[-livro_hp_meio]

if numero_hp_div.is_integer():
    print("Não há um livro do meio, pois o numero de livros é par")
else:
    print(f"O livro do meio de HP é: {livro_HP_meio}")
# Out:
#  Qual o livro do meio de cada?
#  Twilight
# Não há um livro do meio, pois o numero de livros é par
#  Tolkien
# O livro do meio de tolk é: O Retorno do Rei
#  Happy Potter
# O livro do meio de HP é: Harry Potter e o Cálice de Fogo

# %% [markdown]
# Aula 2 e 3 - Notas

# %%
#aula 2 e 3

import random
alunos = ["Alice", "Bob", "Charlie", "David", "Eve", "Frank", "Grace", "Henry", "Isabel", "Jack",
            "Katie", "Liam", "Mia", "Noah", "Olivia", "Patrick", "Quinn", "Rachel", "Sam", "Tina",
            "Ursula", "Victor", "Wendy", "Xander", "Yvonne", "Zack", "Amelia", "Ben", "Catherine", "Daniel",
            "Emma", "Finn", "Gabriella", "Hannah", "Ian", "Jessica", "Kevin", "Lily", "Michael", "Nora"]
notas = [round(random.uniform(0, 10), 1) for _ in range(40)]

#ajudando a definir cor
def print_in_red(message: str) -> None:
    print(f'\33[31m{message}\033[0m')

def print_in_green(message: str) -> None:
    print(f'\33[32m{message}\033[0m')

#tabela alunos
message1 = 'Alunos'
message2 = 'Notas'
message3 = 'Status'
align = "^" # ['<', '>', '^'] 
width = 40
print(f'|{message1:{align}{width}}{message2:{align}{width}}{message3:{align}{width}}|')    

for index in range(0,40):
        if notas[index] >= 5:
                status = "Passed"
                color = "\33[31m"
        else:
                status = "Failed"
                color = "\33[32m"

        print(f'|{alunos[index]:{align}{width}}{notas[index]:{align}{width}}{color}{status:{align}{width}}\033[0m|')

fill = "."
width = 129
print (f' {"":{fill}{align}{width}} ') 
soma = 0 
for g in notas:
    soma = soma + g
media =soma/40
if media >= 5:
        status = "Passed"
        color = "\33[31m"
else:
        status = "Failed"
        color = "\33[32m"
message4 = f"Class media is {media} and {color}{status}\033[0m"                 
print(f"|{message4:{align}{width}}|")

#tabela alunos reprovados
message5 = 'Alunos reprovados'
message6 = 'Notas'
align = "^"
width = 40
print_in_red(f"|{message5:{align}{width}}{message6:{align}{width}}|")

width = 40
for index in range(0,40):
    if notas[index] < 5:
        print(f'|{alunos[index]:{align}{width}}{notas[index]:{align}{width}}|')
# Out:
# |                 Alunos                                  Notas                                   Status                 |
# |                 Alice                                    3.6                                    Failed                 |
# |                  Bob                                     7.5                                    Passed                 |
# |                Charlie                                   9.8                                    Passed                 |
# |                 David                                    3.8                                    Failed                 |
# |                  Eve                                     9.0                                    Passed                 |
# |                 Frank                                    0.1                                    Failed                 |
# |                 Grace                                    1.7                                    Failed                 |
# ...

# %%
#testando cores e estilos
message0 = 'try'
align = "^" # ['<', '>', '^'] 
width = 40
color = "\33[35m"
style = "\33[1m"
background = "\33[47m"
print(f'|{color}{style}{background}{message0:{align}{width}}\033[0m|')

print(f"{message0:_^40}")

def main():
    today = datetime.datetime.now #porque nao tem datetime?
    print(f"Today is: {today}")
    print(f"{today:%d-%m-%Y %H:%M %A}")
# Out:
# |                  try                   |
# __________________try___________________

# %%
#colorama
from colorama import init, Fore
init(autoreset = True) #Set autoreset to True else style configurations would be forwarded to the next print statement
print(Fore.RED + "Hello World")
print(Fore.YELLOW + "Are you convinced yet?")
print(Fore.GREEN + "Once you go colorama, you never go back-around(a)") #Find better joke

# colorspep8.py
def colors_16(color_):
    return("\033[2;{num}m {num} \033[0;0m".format(num=str(color_)))


def colors_256(color_):
    num1 = str(color_)
    num2 = str(color_).ljust(3, ' ')
    if color_ % 16 == 0:
        return(f"\033[38;5;{num1}m {num2} \033[0;0m\n")
    else:
        return(f"\033[38;5;{num1}m {num2} \033[0;0m")

print("The 16 colors scheme is:")
print(' '.join([colors_16(x) for x in range(30, 38)]))
print("\nThe 256 colors scheme is:")
print(' '.join([colors_256(x) for x in range(256)]))
# Out:
# Hello World
# Are you convinced yet?
# Once you go colorama, you never go back-around(a)
